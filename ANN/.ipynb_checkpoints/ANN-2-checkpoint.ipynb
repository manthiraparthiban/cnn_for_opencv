# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
# Out:
# Downloading Cal. housing from https://ndownloader.figshare.com/files/5976036 to C:\Users\Admin\scikit_learn_data

# %%
print(housing.feature_names)
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']

# %%
from sklearn.model_selection import train_test_split
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %%
X_train.shape
# Out:
# (11610, 8)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])
# keras.layers.Dense(30, activation="relu", input_shape=X_train.shape[1:])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 30)                270
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                930
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 31
# =================================================================
# Total params: 1,231
# Trainable params: 1,231
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss="mean_squared_error", 
              optimizer=keras.optimizers.SGD(lr=1e-3), 
              metrics=['mae'])

# %%
model_history = model.fit(X_train, y_train, epochs=20, validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/20
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD4C23268> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD4C23268> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 11610/11610 [==============================] - 1s 116us/sample - loss: 1.8631 - mae: 1.0009 - val_loss: 3.2403 - val_mae: 0.6867
# Epoch 2/20
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.6723 - mae: 0.6092 - val_loss: 0.6939 - val_mae: 0.5660
# Epoch 3/20
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.5927 - mae: 0.5608 - val_loss: 0.5531 - val_mae: 0.5386
# Epoch 4/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5550 - mae: 0.5401 - val_loss: 0.5519 - val_mae: 0.5200
# Epoch 5/20
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5278 - mae: 0.5238 - val_loss: 0.5715 - val_mae: 0.5111
# Epoch 6/20
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.5032 - mae: 0.5098 - val_loss: 0.5591 - val_mae: 0.4969
# Epoch 7/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4863 - mae: 0.5026 - val_loss: 0.4593 - val_mae: 0.4840
# Epoch 8/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4701 - mae: 0.4920 - val_loss: 0.4651 - val_mae: 0.4777
# Epoch 9/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4586 - mae: 0.4862 - val_loss: 0.4392 - val_mae: 0.4669
# Epoch 10/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4476 - mae: 0.4793 - val_loss: 0.4257 - val_mae: 0.4623
# Epoch 11/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4391 - mae: 0.4745 - val_loss: 0.4122 - val_mae: 0.4587
# Epoch 12/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4316 - mae: 0.4704 - val_loss: 0.4052 - val_mae: 0.4544
# Epoch 13/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4255 - mae: 0.4669 - val_loss: 0.4025 - val_mae: 0.4529
# Epoch 14/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4203 - mae: 0.4641 - val_loss: 0.3962 - val_mae: 0.4484
# Epoch 15/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4154 - mae: 0.4615 - val_loss: 0.3906 - val_mae: 0.4457
# Epoch 16/20
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4110 - mae: 0.4586 - val_loss: 0.3923 - val_mae: 0.4424
# Epoch 17/20
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4076 - mae: 0.4565 - val_loss: 0.3851 - val_mae: 0.4408
# Epoch 18/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4036 - mae: 0.4538 - val_loss: 0.3802 - val_mae: 0.4421
# Epoch 19/20
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.4007 - mae: 0.4531 - val_loss: 0.3744 - val_mae: 0.4358
# Epoch 20/20
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3976 - mae: 0.4510 - val_loss: 0.3716 - val_mae: 0.4339

# %%
mae_test = model.evaluate(X_test, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
model_history.history
# Out:
# {'loss': [1.8630863191288776,
#   0.6723268832039155,
#   0.5927273134133818,
#   0.5549557611153724,
#   0.5278301263861775,
#   0.5032001591981433,
#   0.48625867835002967,
#   0.47013836985102614,
#   0.4585774309670073,
#   0.44755741841417257,
#   0.43912484500040583,
#   0.431604173376476,
#   0.42550204823902205,
#   0.4202936603220037,
#   0.41540779366665725,
#   0.41102040187743694,
#   0.4076157877354864,
#   0.40358214730029474,
#   0.4007209645377265,
#   0.39763178234465874],
#  'mae': [1.000874,
#   0.60915804,
#   0.56077474,
#   0.5401411,
#   0.5238083,
#   0.5097514,
#   0.5025851,
#   0.49197477,
#   0.48624775,
#   0.4792753,
#   0.47449708,
#   0.47036856,
#   0.4668606,
#   0.4640983,
#   0.46149576,
#   0.45862278,
#   0.45648307,
#   0.45378846,
#   0.4530758,
#   0.45097804],
#  'val_loss': [3.2403190678712317,
#   0.6938523369550089,
#   0.5531256486741147,
#   0.5519348537506059,
#   0.5714834211023587,
#   0.5590506266099846,
#   0.4592994913266303,
#   0.4650563666524813,
#   0.43920233128760827,
#   0.425675519384463,
#   0.4121819322346409,
#   0.4051738725460161,
#   0.402460306081969,
#   0.3961633677091401,
#   0.390571343529132,
#   0.39229309762941156,
#   0.38512837672726435,
#   0.38015732794461016,
#   0.37442397419796436,
#   0.371552056751818],
#  'val_mae': [0.6867205,
#   0.56597763,
#   0.5385625,
#   0.5200022,
#   0.5111487,
#   0.4968765,
#   0.48398253,
#   0.47765198,
#   0.4669119,
#   0.46231237,
#   0.4587033,
#   0.45443857,
#   0.45288393,
#   0.44838187,
#   0.4456859,
#   0.44239554,
#   0.44079703,
#   0.4421355,
#   0.43575606,
#   0.43385834]}

# %%
pd.DataFrame(model_history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)

plt.show()

# %%
X_new = X_test[:3]

# %%
y_pred = model.predict(X_new)
print (y_pred)
print(y_test[:3])
# Out:
# [[0.5269089]
#  [1.885108 ]
#  [3.3870173]]
# [0.477   0.458   5.00001]

# %%
# Functional API

# %%
input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation="relu")(input_)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model = keras.models.Model(inputs=[input_], outputs=[output])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           930         dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss="mean_squared_error", 
              optimizer=keras.optimizers.SGD(lr=1e-3), 
              metrics=['mae'])

# %%
model_history = model.fit(X_train, y_train, epochs=80, validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/80
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD6487AE8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD6487AE8> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 11610/11610 [==============================] - 1s 110us/sample - loss: 1.6833 - mae: 0.9074 - val_loss: 0.7870 - val_mae: 0.6011
# Epoch 2/80
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6810 - mae: 0.6000 - val_loss: 0.6489 - val_mae: 0.5738
# Epoch 3/80
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.6261 - mae: 0.5769 - val_loss: 0.5921 - val_mae: 0.5523
# Epoch 4/80
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.5879 - mae: 0.5583 - val_loss: 0.5435 - val_mae: 0.5333
# Epoch 5/80
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.5577 - mae: 0.5420 - val_loss: 0.6292 - val_mae: 0.5272
# Epoch 6/80
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.5310 - mae: 0.5289 - val_loss: 0.4943 - val_mae: 0.5070
# Epoch 7/80
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.5118 - mae: 0.5197 - val_loss: 0.5000 - val_mae: 0.5013
# Epoch 8/80
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.4948 - mae: 0.5095 - val_loss: 0.4617 - val_mae: 0.4909
# Epoch 9/80
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4810 - mae: 0.5030 - val_loss: 0.4948 - val_mae: 0.4851
# Epoch 10/80
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4688 - mae: 0.4959 - val_loss: 0.4603 - val_mae: 0.4783
# Epoch 11/80
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4590 - mae: 0.4902 - val_loss: 0.4700 - val_mae: 0.4754
# Epoch 12/80
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4504 - mae: 0.4853 - val_loss: 0.4343 - val_mae: 0.4676
# Epoch 13/80
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.4430 - mae: 0.4804 - val_loss: 0.4533 - val_mae: 0.4680
# Epoch 14/80
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4368 - mae: 0.4774 - val_loss: 0.4289 - val_mae: 0.4609
# Epoch 15/80
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4310 - mae: 0.4736 - val_loss: 0.4372 - val_mae: 0.4601
# Epoch 16/80
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4256 - mae: 0.4705 - val_loss: 0.4253 - val_mae: 0.4549
# Epoch 17/80
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4214 - mae: 0.4672 - val_loss: 0.4469 - val_mae: 0.4561
# Epoch 18/80
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.4168 - mae: 0.4645 - val_loss: 0.4305 - val_mae: 0.4544
# Epoch 19/80
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.4132 - mae: 0.4629 - val_loss: 0.4422 - val_mae: 0.4504
# Epoch 20/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.
80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3606 - mae: 0.4261 - val_loss: 0.3439 - val_mae: 0.4175
# Epoch 55/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3601 - mae: 0.4257 - val_loss: 0.3769 - val_mae: 0.4190
# Epoch 56/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3590 - mae: 0.4246 - val_loss: 0.3831 - val_mae: 0.4205
# Epoch 57/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3583 - mae: 0.4245 - val_loss: 0.4151 - val_mae: 0.4212
# Epoch 58/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3578 - mae: 0.4240 - val_loss: 0.4253 - val_mae: 0.4219
# Epoch 59/80
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3575 - mae: 0.4237 - val_loss: 0.3431 - val_mae: 0.4148
# Epoch 60/80
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3564 - mae: 0.4226 - val_loss: 0.4060 - val_mae: 0.4225
# Epoch 61/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3559 - mae: 0.4227 - val_loss: 0.3589 - val_mae: 0.4183
# Epoch 62/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3552 - mae: 0.4224 - val_loss: 0.4092 - val_mae: 0.4184
# Epoch 63/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3549 - mae: 0.4215 - val_loss: 0.3837 - val_mae: 0.4182
# Epoch 64/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3543 - mae: 0.4210 - val_loss: 0.3772 - val_mae: 0.4189
# Epoch 65/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3540 - mae: 0.4212 - val_loss: 0.3348 - val_mae: 0.4132
# Epoch 66/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3531 - mae: 0.4210 - val_loss: 0.3612 - val_mae: 0.4153
# Epoch 67/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3527 - mae: 0.4200 - val_loss: 0.3583 - val_mae: 0.4132
# Epoch 68/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3519 - mae: 0.4199 - val_loss: 0.4010 - val_mae: 0.4157
# Epoch 69/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3511 - mae: 0.4192 - val_loss: 0.3371 - val_mae: 0.4095
# Epoch 70/80
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3512 - mae: 0.4189 - val_loss: 0.3890 - val_mae: 0.4155
# Epoch 71/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3506 - mae: 0.4190 - val_loss: 0.3608 - val_mae: 0.4122
# Epoch 72/80
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3500 - mae: 0.4180 - val_loss: 0.3870 - val_mae: 0.4146
# Epoch 73/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3497 - mae: 0.4180 - val_loss: 0.3467 - val_mae: 0.4105
# Epoch 74/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3491 - mae: 0.4174 - val_loss: 0.3552 - val_mae: 0.4128
# Epoch 75/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3484 - mae: 0.4171 - val_loss: 0.3790 - val_mae: 0.4132
# Epoch 76/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3478 - mae: 0.4168 - val_loss: 0.3639 - val_mae: 0.4119
# Epoch 77/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3477 - mae: 0.4167 - val_loss: 0.3333 - val_mae: 0.4087
# Epoch 78/80
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3469 - mae: 0.4163 - val_loss: 0.3944 - val_mae: 0.4126
# Epoch 79/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3469 - mae: 0.4157 - val_loss: 0.3566 - val_mae: 0.4107
# Epoch 80/80
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3460 - mae: 0.4155 - val_loss: 0.3892 - val_mae: 0.4129

# %%
mae_test = model.evaluate(X_test, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
model_history.history
# Out:
# {'loss': [1.6832873948682083,
#   0.681045098185642,
#   0.6261378346487533,
#   0.587947431111726,
#   0.557684945495451,
#   0.5310406728205652,
#   0.5117969840996025,
#   0.4947750826933382,
#   0.480992919437645,
#   0.4687800904269058,
#   0.45898503266358354,
#   0.45036461672630934,
#   0.44302963067702855,
#   0.43675988641512176,
#   0.43095847440115037,
#   0.4256359363197767,
#   0.42135412992073684,
#   0.4168333565593279,
#   0.41322006397366423,
#   0.40956150104935884,
#   0.4062340499408075,
#   0.40299047795377035,
#   0.4001957259796284,
#   0.39760911435941293,
#   0.394945014873319,
#   0.3925419073336911,
#   0.39058859913026744,
#   0.3884677025005799,
#   0.4420613313830176,
#   0.430766677656223,
#   0.4197600582003285,
#   0.41932360000850616,
#   0.468617256875186,
#   0.44324239336088955,
#   0.44535856698988635,
#   0.4297461715856572,
#   0.4092548573741001,
#   0.4674089543964204,
#   0.4026834251421675,
#   0.39337467222404726,
#   0.4203484788344504,
#   0.39239830068223547,
#   0.38159087338034803,
#   0.4560243812719365,
#   0.4421846444446603,
#   0.3792109354290851,
#   0.3908481821918364,
#   0.4371999629631215,
#   0.35895437933985885,
#   0.43297610801165726,
#   0.3712542189646137,
#   0.44304884569743497,
#   0.4083737844952625,
#   0.35687951916101984,
#   0.3700742171793329,
#   0.40484323614789536,
#   0.4240363159999059,
#   0.40692852508344085,
#   0.38207330398781353,
#   0.43783693489948294,
#   0.343904998744489,
#   0.37691527752913245,
#   0.38305640633408106,
#   0.4150956870280495,
#   0.42530039316307977,
#   0.34311180625313015,
#   0.4060262668194389,
#   0.35893370191102186,
#   0.4091859722322272,
#   0.38366346217557135,
#   0.37716618070152685,
#   0.33481826594325614,
#   0.36118722964626876,
#   0.3582557249669881,
#   0.40096934961410147,
#   0.33713265934655834,
#   0.3890227036420689,
#   0.3608000415471173,
#   0.3869818210139755,
#   0.346726234076251,
#   0.3552103553169457,
#   0.3789997627953842,
#   0.36390559620943486,
#   0.3332954713386467,
#   0.3943691902459438,
#   0.35658963001513666,
#   0.38923119845624427],
#  'val_mae': [0.60114926,
#   0.57383436,
#   0.55234355,
#   0.5332838,
#   0.52723396,
#   0.506999,
#   0.50127417,
#   0.49087483,
#   0.48509488,
#   0.47831908,
#   0.47537437,
#   0.46755376,
#   0.46799266,
#   0.46087152,
#   0.46007982,
#   0.45492238,
#   0.45612386,
#   0.4544384,
#   0.45036942,
#   0.44796416,
#   0.44735864,
#   0.445711,
#   0.44606847,
#   0.44210473,
#   0.44215813,
#   0.44135562,
#   0.4394266,
#   0.43949184,
#   0.43868566,
#   0.4344951,
#   0.4382229,
#   0.43185994,
#   0.4322681,
#   0.4324462,
#   0.43211848,
#   0.42953444,
#   0.43592048,
#   0.43251348,
#   0.4265095,
#   0.4256339,
#   0.42751017,
#   0.4242386,
#   0.4277451,
#   0.42501205,
#   0.42688814,
#   0.4244829,
#   0.42012444,
#   0.4221767,
#   0.4260252,
#   0.42541894,
#   0.42474324,
#   0.42202842,
#   0.4260714,
#   0.41747212,
#   0.41904572,
#   0.42051387,
#   0.4211906,
#   0.42189777,
#   0.41480425,
#   0.42246002,
#   0.4182834,
#   0.41840288,
#   0.41823918,
#   0.41894406,
#   0.41319382,
#   0.41530582,
#   0.4132406,
#   0.41570798,
#   0.4095258,
#   0.41547897,
#   0.41215113,
#   0.41464713,
#   0.41051438,
#   0.41281763,
#   0.4131526,
#   0.41194415,
#   0.40869263,
#   0.41258347,
#   0.41071796,
#   0.41290265]}

# %%
pd.DataFrame(model_history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)

plt.show()

# %%
# Saving and Restoring

# %%
model.save("my_Func_model.h5")

# %%
# %pwd
# Out:
# 'C:\\Users\\Admin\\Desktop\\CNN for Computer Vision\\ANN'

# %%
del model

# %%
keras.backend.clear_session()

# %%
model = keras.models.load_model("my_Func_model.h5")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 30)           270         input_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 30)           930         dense_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 38)           0           input_1[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            39          concatenate[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
y_pred = model.predict(X_new)
print (y_pred)
# Out:
# [[0.7352998]
#  [1.6823621]
#  [4.127731 ]]

# %% [markdown]
# # Using Callbacks during Training

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=1e-3))

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("Model-{epoch:02d}.h5")

# %%
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-4366750ca4f1> in <module>
# ----> 1 history = model.fit(X_train, y_train, epochs=10,
#       2                     validation_data=(X_valid, y_valid),
#       3                     callbacks=[checkpoint_cb])
#
# NameError: name 'model' is not defined

# %%
del model
keras.backend.clear_session()

# %%
model = keras.models.load_model("Model-10.h5")

# %%
mse_test = model.evaluate(X_test, y_test,batch_size=5160)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
print (mse_test)
# Out:
# 0.43820998072624207

# %%
model.metrics_names
# Out:
# ['loss']

# %%
y_pred = model.predict(X_test)

# %%
y_diff=y_pred-y_test

# %%
y_pred.shape
# Out:
# (5160, 1)

# %%
mse = (y_diff * y_diff)

# %% [markdown]
# ### Best Model Only

# %%
del model
keras.backend.clear_session()

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=1e-3))

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("Best_Model.h5", save_best_only=True)

# %%
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD4C55B70> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FD4C55B70> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 11610/11610 [==============================] - 1s 103us/sample - loss: 1.4530 - val_loss: 0.7972
# Epoch 2/10
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.7402 - val_loss: 0.6640
# Epoch 3/10
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.6512 - val_loss: 0.6182
# Epoch 4/10
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.5951 - val_loss: 0.5563
# Epoch 5/10
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.5534 - val_loss: 0.5014
# Epoch 6/10
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.5197 - val_loss: 0.4723
# Epoch 7/10
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4930 - val_loss: 0.4516
# Epoch 8/10
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.4724 - val_loss: 0.4380
# Epoch 9/10
# 11610/11610 [==============================] - 1s 73us/sample - loss: 0.4559 - val_loss: 0.4378
# Epoch 10/10
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.4429 - val_loss: 0.4325

# %%
del model
keras.backend.clear_session()

# %%
model = keras.models.load_model("Best_Model.h5") # rollback to best model
mse_test = model.evaluate(X_test, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %% [markdown]
# ### Best Model Only

# %%
del model
keras.backend.clear_session()

# %%
model = keras.models.Sequential([
    keras.layers.Dense(30, activation="relu", input_shape=[8]),
    keras.layers.Dense(30, activation="relu"),
    keras.layers.Dense(1)
])

# %%
model.compile(loss="mse", optimizer=keras.optimizers.SGD(lr=1e-3))

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint("early_stop_model.h5", save_best_only=True)

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10,
                                                  restore_best_weights=True)

#     patience: Number of epochs with no improvement after which training will be stopped.

# %%
history = model.fit(X_train, y_train, epochs=200,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/200
# WARNING:tensorflow:Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FF2DC3048> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# WARNING: Entity <function Function._initialize_uninitialized_variables.<locals>.initialize_variables at 0x0000021FF2DC3048> could not be transformed and will be executed as-is. Please report this to the AutoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: module 'gast' has no attribute 'Num'
# 11610/11610 [==============================] - 1s 116us/sample - loss: 2.5576 - val_loss: 2.2008
# Epoch 2/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 1.0781 - val_loss: 0.8693
# Epoch 3/200
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.8431 - val_loss: 0.8327
# Epoch 4/200
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.7697 - val_loss: 0.7867
# Epoch 5/200
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.7245 - val_loss: 0.6680
# Epoch 6/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.6849 - val_loss: 0.6689
# Epoch 7/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6512 - val_loss: 0.6133
# Epoch 8/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.6212 - val_loss: 0.5908
# Epoch 9/200
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.5944 - val_loss: 0.5488
# Epoch 10/200
# 11610/11610 [==============================] - 1s 78us/sample - loss: 0.5693 - val_loss: 0.5261
# Epoch 11/200
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5466 - val_loss: 0.5053
# Epoch 12/200
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.5258 - val_loss: 0.4861
# Epoch 13/200
# 11610/11610 [==============================] - 1s 74us/sample - loss: 0.5071 - val_loss: 0.4710
# Epoch 14/200
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4904 - val_loss: 0.4551
# Epoch 15/200
# 11610/11610 [==============================] - 1s 81us/sample - loss: 0.4757 - val_loss: 0.4400
# Epoch 16/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4629 - val_loss: 0.4291
# Epoch 17/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4521 - val_loss: 0.4285
# Epoch 18/200
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4423 - val_loss: 0.4120
# Epoch 19/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.4345 - val_loss: 0.4284
# Epoch 20/200
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4274 - val_loss: 0.4011
# Epoch 21/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.4215 - val_loss: 0.4207
# Epoch 22/200
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4162 - val_loss: 0.3938
# Epoch 23/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.4112 - val_loss: 0.4009
# Epoch 24/200
# 11610/11610 [==============================] - 1s 72us/sample - loss: 0.4072 - val_loss: 0.3836
# Epoch 25/200
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.4033 - val_loss: 0.3972
# Epoch 26/200
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.3996 - val_loss: 0.4396
# Epoch 27/200
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3969 - val_loss: 0.3874
# Epoch 28/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3934 - val_loss: 0.4158
# Epoch 29/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3908 - val_loss: 0.3948
# Epoch 30/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3883 - val_loss: 0.3930
# Epoch 31/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3857 - val_loss: 0.4290
# Epoch 32/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3835 - val_loss: 0.3687
# Epoch 33/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3815 - val_loss: 0.3744
# Epoch 34/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3794 - val_loss: 0.4261
# Epoch 35/200
# 11610/11610 [==============================] - 1s 75us/sample - loss: 0.3779 - val_loss: 0.3570
# Epoch 36/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3758 - val_loss: 0.3703
# Epoch 37/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3736 - val_loss: 0.4710
# Epoch 38/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3727 - val_loss: 0.4039
# Epoch 39/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3710 - val_loss: 0.3674
# Epoch 40/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3693 - val_loss: 0.3781
# Epoch 41/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3678 - val_loss: 0.4334
# Epoch 42/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3670 - val_loss: 0.3451
# Epoch 43/200
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3653 - val_loss: 0.4632
# Epoch 44/200
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3644 - val_loss: 0.3434
# Epoch 45/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3629 - val_loss: 0.4924
# Epoch 46/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3623 - val_loss: 0.3697
# Epoch 47/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3608 - val_loss: 0.3442
# Epoch 48/200
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3597 - val_loss: 0.3598
# Epoch 49/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3583 - val_loss: 0.3839
# Epoch 50/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3573 - val_loss: 0.4332
# Epoch 51/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3569 - val_loss: 0.3724
# Epoch 52/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3559 - val_loss: 0.3681
# Epoch 53/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3546 - val_loss: 0.4483
# Epoch 54/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3541 - val_loss: 0.3396
# Epoch 55/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3534 - val_loss: 0.3536
# Epoch 56/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3519 - val_loss: 0.3706
# Epoch 57/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3510 - val_loss: 0.4120
# Epoch 58/200
# 11610/11610 [==============================] - 1s 64us/sample - loss: 0.3502 - val_loss: 0.4281
# Epoch 59/200
# 11610/11610 [==============================] - 1s 65us/sample - loss: 0.3498 - val_loss: 0.3381
# Epoch 60/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3487 - val_loss: 0.3696
# Epoch 61/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3478 - val_loss: 0.3523
# Epoch 62/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3471 - val_loss: 0.3851
# Epoch 63/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3464 - val_loss: 0.3665
# Epoch 64/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3456 - val_loss: 0.3821
# Epoch 65/200
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3451 - val_loss: 0.3301
# Epoch 66/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3442 - val_loss: 0.3518
# Epoch 67/200
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3436 - val_loss: 0.3602
# Epoch 68/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3427 - val_loss: 0.3952
# Epoch 69/200
# 11610/11610 [==============================] - 1s 66us/sample - loss: 0.3420 - val_loss: 0.3290
# Epoch 70/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3417 - val_loss: 0.3566
# Epoch 71/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3409 - val_loss: 0.3634
# Epoch 72/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3405 - val_loss: 0.3729
# Epoch 73/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3399 - val_loss: 0.3479
# Epoch 74/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3394 - val_loss: 0.3513
# Epoch 75/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3388 - val_loss: 0.3836
# Epoch 76/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3382 - val_loss: 0.3700
# Epoch 77/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3381 - val_loss: 0.3277
# Epoch 78/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3374 - val_loss: 0.3677
# Epoch 79/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3370 - val_loss: 0.3676
# Epoch 80/200
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3365 - val_loss: 0.4034
# Epoch 81/200
# 11610/11610 [==============================] - 1s 62us/sample - loss: 0.3362 - val_loss: 0.3348
# Epoch 82/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3356 - val_loss: 0.3739
# Epoch 83/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3355 - val_loss: 0.3549
# Epoch 84/200
# 11610/11610 [==============================] - 1s 61us/sample - loss: 0.3350 - val_loss: 0.3689
# Epoch 85/200
# 11610/11610 [==============================] - 1s 60us/sample - loss: 0.3347 - val_loss: 0.3322
# Epoch 86/200
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3343 - val_loss: 0.3312
# Epoch 87/200
# 11610/11610 [==============================] - 1s 63us/sample - loss: 0.3338 - val_loss: 0.3805

# %%
model = keras.models.load_model("early_stop_model.h5")
mse_test = model.evaluate(X_test, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
